# %% [markdown]
# <a href="https://colab.research.google.com/github/unt-iialab/INFO5731_Spring2020/blob/master/Assignments/INFO5731_Assignment_Three.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Three**
#
# In this assignment, you are required to conduct information extraction, semantic analysis based on **the dataset you collected from assignment two**. You may use scipy and numpy package in this assignment.

# %% [markdown]
# # **Question 1: Understand N-gram**

# %% [markdown]
# (45 points). Write a python program to conduct N-gram analysis based on the dataset in your assignment two:
#
# (1) Count the frequency of all the N-grams (N=3).
#
# (2) Calculate the probabilities for all the bigrams in the dataset by using the fomular count(w2 w1) / count(w2). For example, count(really like) / count(really) = 1 / 3 = 0.33.
#
# (3) Extract all the **noun phrases** and calculate the relative probabilities of each review in terms of other reviews (abstracts, or tweets) by using the fomular frequency (noun phrase) / max frequency (noun phrase) on the whole dataset. Print out the result in a table with column name the all the noun phrases and row name as all the 100 reviews (abstracts, or tweets).

# %%
# Write your code here

# !apt-get update
# !apt install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin
# !pip install selenium
# Out:
# Hit:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu bionic-updates InRelease
# Hit:5 http://security.ubuntu.com/ubuntu bionic-security InRelease
# Hit:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease
# Ign:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:10 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:12 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:13 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# chromium-chromedriver is already the newest version (99.0.4844.84-0ubuntu0.18.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 96 not upgraded.
# cp: '/usr/lib/chromium-browser/chromedriver' and '/usr/bin/chromedriver' are the same file
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (4.1.3)
# Requirement already satisfied: urllib3[secure,socks]~=1.26 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.26.9)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.7/dist-packages (from selenium) (0.20.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.1.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in /usr/local/lib/python3.7/dist-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.7/dist-packages (from trio-websocket~=0.9->selenium) (1.1.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (2021.10.8)
# Requirement already satisfied: pyOpenSSL>=0.14 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (22.0.0)
# Requirement already satisfied: cryptography>=1.3.4 in /usr/local/lib/python3.7/dist-packages (from urllib3[secure,socks]~=1.26->selenium) (36.0.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=1.3.4->urllib3[secure,socks]~=1.26->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.13.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from h11<1,>=0.9.0->wsproto>=0.14->trio-websocket~=0.9->selenium) (3.10.0.2)

# %%
from selenium import webdriver
options = webdriver.ChromeOptions()
options.add_argument('-headless')
options.add_argument('-no-sandbox')
options.add_argument('-disable-dev-shm-usage')

# %%
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.by import By
import pandas as pd
import time

driver = webdriver.Chrome('chromedriver',options=options)
link = 'https://www.imdb.com/title/tt7286456/reviews?ref_=tt_urv'
title_array = []
review_array = []
driver.get(link)
for num in range(4):
  driver.find_element_by_class_name("ipl-load-more__button").click()
  time.sleep(5)
  listOfTitle = driver.find_elements(By.CLASS_NAME, "title")
  listOfReviews = driver.find_elements(By.CLASS_NAME, "text")
for ele, sub_ele in zip(listOfTitle, listOfReviews):
      title_array.append((ele.text).replace('\n',''))
      review_array.append(sub_ele.text)
df = pd.DataFrame(list(zip(title_array, review_array)), columns =['Title', 'Review'])
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   if sys.path[0] == '':
# Length of data frame is 125
#                                                  Title  \
# 0    Outstanding movie with a haunting performance ...
# 1                       Only certain people can relate
# 2                             Perfect in every aspect.
# 3                                        MASTERPIECE 😍
# 4                                     The Hype is real
# ..                                                 ...
# 120                      Best film in the 21st century
# 121                                           a mirror
# 122                                      Amazing movie
# 123  Arthur Fleck: a case study of a young person's...
# 124  A gorgeously crafted baroque film with a sheer...
#
#                                                 Review
# 0    Every once in a while a movie comes, that trul...
# 1    This is a movie that only those who have felt ...
# 2    Truly a masterpiece, The Best Hollywood film o...
# 3    Joaquin Phoenix gives a tour de force performa...
# 4    Most of the time movies are anticipated like t...
# ..                                                 ...
# 120
# 121  In many aspects, it is a mirror. For society, ...
# 122  Best acting and story. This is an Oscar winnin...
# 123  This film surpassed all other films in portray...
# 124  A confused representation of insanity from a p...
#
# [125 rows x 2 columns]

# %%
import nltk
nltk.download()
# Out:
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> i
#     Error loading i: Package 'i' not found in index
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> q
# True

# %%
df['Lower Case'] = df['Review'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df['Removal of Punctuation'] = df['Lower Case'].str.replace('[^\w\s]','')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   """Entry point for launching an IPython kernel.

# %%
import re
df['Removal of Special Characters'] = df['Removal of Punctuation'].apply(lambda x: ''.join(re.sub(r"[^a-zA-Z0-9]+", ' ', charctr) for charctr in x ))

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['Stopwords Removal'] = df['Removal of Punctuation'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))

# %%
from textblob import TextBlob
df['Spelling Correction'] = df['Stopwords Removal'].apply(lambda x: str(TextBlob(x).correct()))

# %%
import nltk
nltk.download('punkt')
df['Tokenization'] = df['Spelling Correction'].apply(lambda x: TextBlob(x).words)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk.stem import PorterStemmer
st = PorterStemmer()
df['After Stemming'] = df['Tokenization'].apply(lambda x: " ".join([st.stem(word) for word in x]))

# %%
from textblob import Word
import nltk
nltk.download('wordnet')

df['After Lemmatization'] = df['After Stemming'].apply(lambda x: " ".join([Word(word).lemmatize() for word in x.split()]))
df.to_csv('/content/sample_data/reviwes.csv',index=False)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
import itertools
import collections
from nltk import ngrams
from nltk.tokenize import word_tokenize

words_sentence = []
for sentence in df['After Lemmatization']:
  words_sentence.append(word_tokenize(sentence))
aftercleaning = [x for x in words_sentence if x != []]
iterations = list(itertools.chain.from_iterable(aftercleaning))

# %%
tri_grams = nltk.trigrams(iterations)
frequency_dist = nltk.FreqDist(tri_grams)
frequency_dist
# Out:
# FreqDist({('everi', 'movi', 'come'): 1,
#           ('movi', 'come', 'truli'): 1,
#           ('come', 'truli', 'make'): 1,
#           ('truli', 'make', 'impact'): 1,
#           ('make', 'impact', 'joaquin'): 1,
#           ('impact', 'joaquin', 'perform'): 1,
#           ('joaquin', 'perform', 'scenographi'): 1,
#           ('perform', 'scenographi', 'brillianc'): 1,
#           ('scenographi', 'brillianc', 'grotesqu'): 1,
#           ('brillianc', 'grotesqu', 'hunt'): 1,
#           ('grotesqu', 'hunt', 'cring'): 1,
#           ('hunt', 'cring', 'hard'): 1,
#           ('cring', 'hard', 'watch'): 1,
#           ('hard', 'watch', 'time'): 1,
#           ('watch', 'time', 'mesmer'): 1,
#           ('time', 'mesmer', 'wont'): 1,
#           ('mesmer', 'wont', 'blink'): 1,
#           ('wont', 'blink', 'eye'): 1,
#           ('blink', 'eye', 'watch'): 1,
#           ('eye', 'watch', 'tragic'): 1,
#           ('watch', 'tragic', 'serious'): 1,
#           ('tragic', 'serious', 'funni'): 1,
#           ('serious', 'funni', 'moment'): 1,
#           ('funni', 'moment', 'emot'): 1,
#           ('moment', 'emot', 'rollercoast'): 1,
#           ('emot', 'rollercoast', 'sometim'): 1,
#           ('rollercoast', 'sometim', 'multipl'): 1,
#           ('sometim', 'multipl', 'emot'): 1,
#           ('multipl', 'emot', 'pop'): 1,
#           ('emot', 'pop', 'time'): 1,
#           ('pop', 'time', 'far'): 1,
#           ('time', 'far', 'typic'): 1,
#           ('far', 'typic', 'actionriddl'): 1,
#           ('typic', 'actionriddl', 'predict'): 1,
#           ('actionriddl', 'predict', 'superhero'): 1,
#           ('predict', 'superhero', 'movi'): 1,
#           ('superhero', 'movi', 'proper'): 1,
#           ('movi', 'proper', 'psycholog'): 1,
#           ('proper', 'psycholog', 'thrillerdrama'): 1,
#           ('psycholog', 'thrillerdrama', 'singl'): 1,
#           ('thrillerdrama', 'singl', 'best'): 1,
#           ('singl', 'best', 'charact'): 1,
#           ('best', 'charact', 'develop'): 1,
#           ('charact', 'develop', 'ever'): 1,
#           ('develop', 'ever', 'seen'): 1,
#           ('ever', 'seen', 'movi'): 2,
#           ('seen', 'movi', 'felt'): 1,
#           ('movi', 'felt', 'alon'): 1,
#           ('felt', 'alon', 'isol'): 1,
#           ('alon', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'relat'): 1,
#           ('truli', 'relat', 'understand'): 1,
#           ('relat', 'understand', 'motiv'): 1,
#           ('understand', 'motiv', 'feel'): 1,
#           ('motiv', 'feel', 'sorri'): 1,
#           ('feel', 'sorri', 'charact'): 1,
#           ('sorri', 'charact', 'lot'): 1,
#           ('charact', 'lot', 'peopl'): 1,
#           ('lot', 'peopl', 'see'): 1,
#           ('peopl', 'see', 'movi'): 1,
#           ('see', 'movi', 'think'): 1,
#           ('movi', 'think', 'encourag'): 1,
#           ('think', 'encourag', 'violenc'): 1,
#           ('encourag', 'violenc', 'truli'): 1,
#           ('violenc', 'truli', 'movi'): 1,
#           ('truli', 'movi', 'encourag'): 1,
#           ('movi', 'encourag', 'everi'): 1,
#           ('encourag', 'everi', 'one'): 1,
#           ('everi', 'one', 'u'): 1,
#           ('one', 'u', 'becom'): 1,
#           ('u', 'becom', 'better'): 1,
#           ('becom', 'better', 'person'): 1,
#           ('better', 'person', 'treat'): 1,
#           ('person', 'treat', 'everyon'): 1,
#           ('treat', 'everyon', 'respect'): 1,
#           ('everyon', 'respect', 'make'): 1,
#           ('respect', 'make', 'feel'): 1,
#           ('make', 'feel', 'like'): 1,
#           ('feel', 'like', 'belong'): 1,
#           ('like', 'belong', 'world'): 1,
#           ('belong', 'world', 'instead'): 1,
#           ('world', 'instead', 'make'): 1,
#           ('instead', 'make', 'feel'): 1,
#           ('make', 'feel', 'isol'): 1,
#           ('feel', 'isol', 'truli'): 1,
#           ('isol', 'truli', 'masterpiec'): 1,
#           ('truli', 'masterpiec', 'best'): 1,
#           ('masterpiec', 'best', 'hollywood'): 1,
#           ('best', 'hollywood', 'film'): 1,
#           ('hollywood', 'film', '2019'): 1,
#           ('film', '2019', 'one'): 1,
#           ('2019', 'one', 'best'): 1,
#           ('one', 'best', 'film'): 1,
#           ('best', 'film', 'decad'): 1,
#           ('film', 'decad', 'truli'): 1,
#           ('decad', 'truli', 'best'): 1,
#           ('truli', 'best', 'film'): 1,
#           ('best', 'film', 'bring'): 1,
#           ('film', 'bring', 'comic'): 1,
#           ('bring', 'comic', 'book'): 1,
#           ('comic', 'book', 'willingli'): 1,
#           ('book', 'willingli', 'realist'): 1,
#           ('willingli', 'realist', 'real'): 1,
#           ('realist', 'real', 'if'): 1,
#           ('real', 'if', 'remark'): 1,
#           ('if', 'remark', 'direct'): 1,
#           ('remark', 'direct', 'cinematographi'): 1,
#           ('direct', 'cinematographi', 'music'): 1,
#           ('cinematographi', 'music', 'act'): 1,
#           ('music', 'act', 'peopl'): 1,
#           ('act', 'peopl', 'surpris'): 1,
#           ('peopl', 'surpris', 'find'): 1,
#           ('surpris', 'find', 'disturb'): 1,
#           ('find', 'disturb', 'violent'): 1,
#           ('disturb', 'violent', 'necess'): 1,
#           ('violent', 'necess', 'messag'): 1,
#           ('necess', 'messag', 'societi'): 1,
#           ('messag', 'societi', 'reflect'): 1,
#           ('societi', 'reflect', 'underappreciatedunrecognizedbulli'): 1,
#           ('reflect', 'underappreciatedunrecognizedbulli', 'peopl'): 1,
#           ('underappreciatedunrecognizedbulli', 'peopl', 'prove'): 1,
#           ('peopl', 'prove', 'someth'): 1,
#           ('prove', 'someth', 'way'): 1,
#           ('someth', 'way', 'show'): 1,
#           ('way', 'show', 'class'): 1,
#           ('show', 'class', 'differ'): 1,
#           ('class', 'differ', 'corrupt'): 1,
#           ('differ', 'corrupt', 'rich'): 1,
#           ('corrupt', 'rich', 'talent'): 1,
#           ('rich', 'talent', 'rule'): 1,
#           ('talent', 'rule', 'other'): 1,
#           ('rule', 'other', 'around'): 1,
#           ('other', 'around', 'exagger'): 1,
#           ('around', 'exagger', 'that'): 1,
#           ('exagger', 'that', 'make'): 1,
#           ('that', 'make', 'differ'): 1,
#           ('make', 'differ', 'believ'): 1,
#           ('differ', 'believ', 'could'): 1,
#           ('believ', 'could', 'multipl'): 1,
#           ('could', 'multipl', 'joke'): 1,
#           ('multipl', 'joke', 'live'): 1,
#           ('joke', 'live', 'societi'): 1,
#           ('live', 'societi', 'could'): 1,
#           ('societi', 'could', 'shake'): 1,
#           ('could', 'shake', 'around'): 1,
#           ('shake', 'around', 'much'): 1,
#           ('around', 'much', 'bitter'): 1,
#           ('much', 'bitter', 'way'): 1,
#           ('bitter', 'way', 'film'): 1,
#           ('way', 'film', 'show'): 1,
#           ('film', 'show', 'make'): 1,
#           ('show', 'make', 'peopl'): 1,
#           ('make', 'peopl', 'comfort'): 1,
#           ('peopl', 'comfort', 'peopl'): 1,
#           ('comfort', 'peopl', 'consid'): 1,
#           ('peopl', 'consid', 'wake'): 1,
#           ('consid', 'wake', 'call'): 1,
#           ('wake', 'call', 'messag'): 1,
#           ('call', 'messag', 'first'): 1,
#           ('messag', 'first', 'film'): 1,
#           ('first', 'film', 'perfect'): 1,
#           ('film', 'perfect', 'film'): 1,
#           ('perfect', 'film', 'joaquin'): 1,
#           ('film', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'give'): 3,
#           ('phoenix', 'give', 'tour'): 1,
#           ('give', 'tour', 'de'): 1,
#           ('tour', 'de', 'forc'): 1,
#           ('de', 'forc', 'perform'): 1,
#           ('forc', 'perform', 'fearless'): 1,
#           ('perform', 'fearless', 'stun'): 1,
#           ('fearless', 'stun', 'emot'): 1,
#           ('stun', 'emot', 'depth'): 1,
#           ('emot', 'depth', 'physic'): 1,
#           ('depth', 'physic', 'imposs'): 1,
#           ('physic', 'imposs', 'talk'): 1,
#           ('imposs', 'talk', 'without'): 1,
#           ('talk', 'without', 'referenc'): 1,
#           ('without', 'referenc', 'heath'): 1,
#           ('referenc', 'heath', 'ledger'): 1,
#           ('heath', 'ledger', 'oscarwin'): 1,
#           ('ledger', 'oscarwin', 'perform'): 1,
#           ('oscarwin', 'perform', 'dark'): 1,
#           ('perform', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'wide'): 1,
#           ('knight', 'wide', 'consid'): 1,
#           ('wide', 'consid', 'definit'): 1,
#           ('consid', 'definit', 'liveact'): 1,
#           ('definit', 'liveact', 'portray'): 1,
#           ('liveact', 'portray', 'joke'): 1,
#           ('portray', 'joke', 'let'): 1,
#           ('joke', 'let', 'talk'): 1,
#           ('let', 'talk', 'fact'): 1,
#           ('talk', 'fact', 'everyon'): 1,
#           ('fact', 'everyon', 'go'): 1,
#           ('everyon', 'go', 'stun'): 1,
#           ('go', 'stun', 'phoenix'): 1,
#           ('stun', 'phoenix', 'accomplish'): 1,
#           ('phoenix', 'accomplish', 'mani'): 1,
#           ('accomplish', 'mani', 'thought'): 1,
#           ('mani', 'thought', 'imposs'): 1,
#           ('thought', 'imposs', 'portray'): 1,
#           ('imposs', 'portray', 'match'): 1,
#           ('portray', 'match', 'potenti'): 1,
#           ('match', 'potenti', 'exce'): 1,
#           ('potenti', 'exce', 'dark'): 1,
#           ('exce', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'clown'): 1,
#           ('knight', 'clown', 'princ'): 1,
#           ('clown', 'princ', 'crime'): 1,
#           ('princ', 'crime', 'time'): 1,
#           ('crime', 'time', 'move'): 1,
#           ('time', 'move', 'anticip'): 1,
#           ('move', 'anticip', 'like'): 1,
#           ('anticip', 'like', 'end'): 1,
#           ('like', 'end', 'fall'): 1,
#           ('end', 'fall', 'short'): 1,
#           ('fall', 'short', 'way'): 1,
#           ('short', 'way', 'short'): 1,
#           ('way', 'short', 'joke'): 1,
#           ('short', 'joke', 'first'): 1,
#           ('joke', 'first', 'time'): 2,
#           ('first', 'time', 'happi'): 1,
#           ('time', 'happi', 'hope'): 1,
#           ('happi', 'hope', 'plea'): 1,
#           ('hope', 'plea', 'ignor'): 1,
#           ('plea', 'ignor', 'complaint'): 1,
#           ('ignor', 'complaint', 'pernici'): 1,
#           ('complaint', 'pernici', 'violenc'): 1,
#           ('pernici', 'violenc', 'embarrass'): 1,
#           ('violenc', 'embarrass', 'say'): 1,
#           ('embarrass', 'say', 'least'): 1,
#           ('say', 'least', 'haven'): 1,
#           ('least', 'haven', 'seen'): 1,
#           ('haven', 'seen', 'comic'): 1,
#           ('seen', 'comic', 'movi'): 1,
#           ('comic', 'movi', 'real'): 1,
#           ('movi', 'real', 'ever'): 1,
#           ('real', 'ever', 'deserv'): 1,
#           ('ever', 'deserv', 'better'): 1,
#           ('deserv', 'better', 'class'): 1,
#           ('better', 'class', 'crimin'): 1,
#           ('class', 'crimin', 'phillip'): 1,
#           ('crimin', 'phillip', 'phoenix'): 1,
#           ('phillip', 'phoenix', 'deliv'): 1,
#           ('phoenix', 'deliv', 'dark'): 1,
#           ('deliv', 'dark', 'joke'): 1,
#           ('dark', 'joke', 'dark'): 1,
#           ('joke', 'dark', 'fall'): 1,
#           ('dark', 'fall', 'love'): 1,
#           ('fall', 'love', 'villain'): 1,
#           ('love', 'villain', 'bad'): 1,
#           ('villain', 'bad', 'gun'): 1,
#           ('bad', 'gun', 'alway'): 1,
#           ('gun', 'alway', 'romant'): 1,
#           ('alway', 'romant', 'anyway'): 1,
#           ('romant', 'anyway', 'let'): 1,
#           ('anyway', 'let', 'start'): 1,
#           ('let', 'start', 'say'): 1,
#           ('start', 'say', 'joaquin'): 1,
#           ('say', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'doesn'): 2,
#           ('phoenix', 'doesn', 'get'): 1,
#           ('doesn', 'get', 'oscar'): 1,
#           ('get', 'oscar', 'movi'): 1,
#           ('oscar', 'movi', 'scar'): 1,
#           ('movi', 'scar', 'cancel'): 1,
#           ('scar', 'cancel', 'phoenix'): 1,
#           ('cancel', 'phoenix', 'amaz'): 1,
#           ('phoenix', 'amaz', 'might'): 1,
#           ('amaz', 'might', 'heard'): 1,
#           ('might', 'heard', 'everi'): 1,
#           ('heard', 'everi', 'review'): 1,
#           ('everi', 'review', 'ever'): 1,
#           ('review', 'ever', 'told'): 1,
#           ('ever', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'best'): 1,
#           ('phillip', 'best', 'stori'): 1,
#           ('best', 'stori', 'line'): 1,
#           ('stori', 'line', 'take'): 1,
#           ('line', 'take', 'visual'): 1,
#           ('take', 'visual', 'breathtak'): 1,
#           ('visual', 'breathtak', 'score'): 1,
#           ('breathtak', 'score', 'org'): 1,
#           ('score', 'org', 'score'): 1,
#           ('org', 'score', 'everi'): 1,
#           ('score', 'everi', 'time'): 1,
#           ('everi', 'time', 'score'): 1,
#           ('time', 'score', 'came'): 1,
#           ('score', 'came', 'felt'): 1,
#           ('came', 'felt', 'uncomfort'): 1,
#           ('felt', 'uncomfort', 'like'): 1,
#           ('uncomfort', 'like', 'someth'): 1,
#           ('like', 'someth', 'horribl'): 1,
#           ('someth', 'horribl', 'happen'): 1,
#           ('horribl', 'happen', 'great'): 1,
#           ('happen', 'great', 'inspir'): 1,
#           ('great', 'inspir', 'taxi'): 1,
#           ('inspir', 'taxi', 'driver'): 2,
#           ('taxi', 'driver', 'king'): 4,
#           ('driver', 'king', 'comedi'): 4,
#           ('king', 'comedi', 'add'): 1,
#           ('comedi', 'add', 'much'): 1,
#           ('add', 'much', 'movi'): 1,
#           ('much', 'movi', 'got'): 1,
#           ('movi', 'got', 'honest'): 1,
#           ('got', 'honest', 'scene'): 1,
#           ('honest', 'scene', 'violent'): 1,
#           ('scene', 'violent', 'disturb'): 1,
#           ('violent', 'disturb', 'honestli'): 1,
#           ('disturb', 'honestli', 'expect'): 1,
#           ('honestli', 'expect', 'wayyyi'): 1,
#           ('expect', 'wayyyi', 'violent'): 1,
#           ('wayyyi', 'violent', 'controversi'): 1,
#           ('violent', 'controversi', 'go'): 1,
#           ('controversi', 'go', 'overal'): 1,
#           ('go', 'overal', 'movi'): 1,
#           ('overal', 'movi', 'great'): 1,
#           ('movi', 'great', 'come'): 1,
#           ('great', 'come', 'oscar'): 1,
#           ('come', 'oscar', 'season'): 1,
#           ('oscar', 'season', 'need'): 1,
#           ('season', 'need', 'nomin'): 1,
#           ('need', 'nomin', 'best'): 1,
#           ('nomin', 'best', 'pictur'): 1,
#           ('best', 'pictur', 'screenplay'): 1,
#           ('pictur', 'screenplay', 'cinematographi'): 1,
#           ('screenplay', 'cinematographi', 'actor'): 1,
#           ('cinematographi', 'actor', 'score'): 1,
#           ('actor', 'score', 'director'): 1,
#           ('score', 'director', 'get'): 1,
#           ('director', 'get', 'peopl'): 1,
#           ('get', 'peopl', 'hate'): 1,
#           ('peopl', 'hate', 'polit'): 1,
#           ('hate', 'polit', 'messag'): 1,
#           ('polit', 'messag', 'peopl'): 1,
#           ('messag', 'peopl', 'think'): 1,
#           ('peopl', 'think', 'need'): 1,
#           ('think', 'need', 'get'): 1,
#           ('need', 'get', 'empti'): 1,
#           ('get', 'empti', 'arthur'): 1,
#           ('empti', 'arthur', 'mad'): 1,
#           ('arthur', 'mad', 'come'): 1,
#           ('mad', 'come', 'point'): 1,
#           ('come', 'point', 'never'): 1,
#           ('point', 'never', 'enjoy'): 1,
#           ('never', 'enjoy', 'masterpiec'): 1,
#           ('enjoy', 'masterpiec', 'joaquin'): 1,
#           ('masterpiec', 'joaquin', 'phoenix'): 2,
#           ('joaquin', 'phoenix', 'told'): 1,
#           ('phoenix', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'overdid'): 1,
#           ('phillip', 'overdid', 'movi'): 1,
#           ('overdid', 'movi', 'actingmus'): 1,
#           ('movi', 'actingmus', 'cinematographi'): 1,
#           ('actingmus', 'cinematographi', 'amaz'): 1,
#           ('cinematographi', 'amaz', 'plea'): 1,
#           ('amaz', 'plea', 'enjoy'): 1,
#           ('plea', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'without'): 1,
#           ('movi', 'without', 'overthink'): 1,
#           ('without', 'overthink', 'seen'): 1,
#           ('overthink', 'seen', 'joke'): 1,
#           ('seen', 'joke', 'yesterday'): 1,
#           ('joke', 'yesterday', 'venic'): 1,
#           ('yesterday', 'venic', 'earli'): 1,
#           ('venic', 'earli', 'inflat'): 1,
#           ('earli', 'inflat', 'screen'): 1,
#           ('inflat', 'screen', 'troubl'): 1,
#           ('screen', 'troubl', 'audit'): 1,
#           ('troubl', 'audit', 'lead'): 1,
#           ('audit', 'lead', 'nearhour'): 1,
#           ('lead', 'nearhour', 'delay'): 1,
#           ('nearhour', 'delay', 'definit'): 1,
#           ('delay', 'definit', 'worth'): 1,
#           ('definit', 'worth', 'joke'): 1,
#           ('worth', 'joke', 'deserv'): 1,
#           ('joke', 'deserv', 'present'): 1,
#           ('deserv', 'present', 'venic'): 1,
#           ('present', 'venic', 'film'): 1,
#           ('venic', 'film', 'festiv'): 1,
#           ('film', 'festiv', 'event'): 1,
#           ('festiv', 'event', 'regard'): 1,
#           ('event', 'regard', 'cinema'): 1,
#           ('regard', 'cinema', 'form'): 1,
#           ('cinema', 'form', 'art'): 1,
#           ('form', 'art', 'film'): 1,
#           ('art', 'film', 'far'): 1,
#           ('film', 'far', 'blockbust'): 1,
#           ('far', 'blockbust', 'mere'): 1,
#           ('blockbust', 'mere', 'entertain'): 1,
#           ('mere', 'entertain', 'movi'): 1,
#           ('entertain', 'movi', 'film'): 1,
#           ('movi', 'film', 'gene'): 1,
#           ('film', 'gene', 'focus'): 1,
#           ('gene', 'focus', 'psychic'): 1,
#           ('focus', 'psychic', 'main'): 1,
#           ('psychic', 'main', 'charact'): 1,
#           ('main', 'charact', 'slowli'): 1,
#           ('charact', 'slowli', 'crumbl'): 1,
#           ('slowli', 'crumbl', 'pressur'): 1,
#           ('crumbl', 'pressur', 'societi'): 1,
#           ('pressur', 'societi', 'thu'): 1,
#           ('societi', 'thu', 'joaquin'): 1,
#           ('thu', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'wonder'): 1,
#           ('phoenix', 'wonder', 'perform'): 1,
#           ('wonder', 'perform', 'earn'): 1,
#           ('perform', 'earn', 'almost'): 1,
#           ('earn', 'almost', 'sure'): 1,
#           ('almost', 'sure', 'nomin'): 1,
#           ('sure', 'nomin', 'scar'): 1,
#           ('nomin', 'scar', 'least'): 1,
#           ('scar', 'least', 'take'): 1,
#           ('least', 'take', 'joke'): 1,
#           ('take', 'joke', 'differ'): 1,
#           ('joke', 'differ', 'ledger'): 1,
#           ('differ', 'ledger', 'id'): 1,
#           ('ledger', 'id', 'say'): 1,
#           ('id', 'say', 'equal'): 1,
#           ('say', 'equal', 'good'): 1,
#           ('equal', 'good', 'main'): 1,
#           ('good', 'main', 'differ'): 1,
#           ('main', 'differ', 'might'): 1,
#           ('differ', 'might', 'ledger'): 1,
#           ('might', 'ledger', 'joke'): 1,
#           ('ledger', 'joke', 'ration'): 1,
#           ('joke', 'ration', 'act'): 1,
#           ('ration', 'act', 'insan'): 1,
#           ('act', 'insan', 'phoenix'): 1,
#           ('insan', 'phoenix', 'insan'): 1,
#           ('phoenix', 'insan', 'root'): 1,
#           ('insan', 'root', 'despit'): 1,
#           ('root', 'despit', 'movi'): 1,
#           ('despit', 'movi', 'superhero'): 1,
#           ('movi', 'superhero', 'villain'): 1,
#           ('superhero', 'villain', 'joke'): 1,
#           ('villain', 'joke', 'much'): 1,
#           ('joke', 'much', 'superior'): 1,
#           ('much', 'superior', 'move'): 1,
#           ('superior', 'move', 'gene'): 1,
#           ('move', 'gene', 'id'): 1,
#           ('gene', 'id', 'exclud'): 1,
#           ('id', 'exclud', 'dark'): 1,
#           ('exclud', 'dark', 'knight'): 1,
#           ('dark', 'knight', 'trilog'): 2,
#           ('knight', 'trilog', 'joke'): 1,
#           ('trilog', 'joke', 'easili'): 1,
#           ('joke', 'easili', 'good'): 1,
#           ('easili', 'good', 'plan'): 1,
#           ('good', 'plan', 'move'): 1,
#           ('plan', 'move', 'least'): 1,
#           ('move', 'least', 'close'): 1,
#           ('least', 'close', 'smallscal'): 1,
#           ('close', 'smallscal', 'film'): 1,
#           ('smallscal', 'film', 'distinct'): 1,
#           ('film', 'distinct', 'style'): 1,
#           ('distinct', 'style', 'cinematographi'): 1,
#           ('style', 'cinematographi', 'can'): 1,
#           ('cinematographi', 'can', 'not'): 1,
#           ('can', 'not', 'appreci'): 1,
#           ('not', 'appreci', 'set'): 1,
#           ('appreci', 'set', 'cinephil'): 1,
#           ('set', 'cinephil', 'refer'): 1,
#           ('cinephil', 'refer', 'howev'): 1,
#           ('refer', 'howev', 'feel'): 1,
#           ('howev', 'feel', 'forc'): 1,
#           ('feel', 'forc', 'overlay'): 1,
#           ('forc', 'overlay', 'oppress'): 1,
#           ('overlay', 'oppress', 'notabl'): 1,
#           ('oppress', 'notabl', 'similar'): 1,
#           ('notabl', 'similar', 'scorses'): 1,
#           ('similar', 'scorses', 'taxi'): 1,
#           ('scorses', 'taxi', 'driver'): 1,
#           ('king', 'comedi', 'also'): 1,
#           ('comedi', 'also', 'chain'): 1,
#           ('also', 'chain', 'modern'): 1,
#           ('chain', 'modern', 'time'): 1,
#           ('modern', 'time', 'somewhat'): 1,
#           ('time', 'somewhat', 'refer'): 1,
#           ('somewhat', 'refer', 'eager'): 1,
#           ('refer', 'eager', 'see'): 1,
#           ('eager', 'see', 'noncomed'): 1,
#           ('see', 'noncomed', 'effort'): 1,
#           ('noncomed', 'effort', 'told'): 1,
#           ('effort', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'movi'): 1,
#           ('phillip', 'movi', 'far'): 1,
#           ('movi', 'far', 'probabl'): 1,
#           ('far', 'probabl', 'best'): 1,
#           ('probabl', 'best', '2019'): 1,
#           ('best', '2019', 'worst'): 1,
#           ('2019', 'worst', 'contest'): 1,
#           ('worst', 'contest', 'far'): 1,
#           ('contest', 'far', 'door'): 1,
#           ('far', 'door', 'gloria'): 1,
#           ('door', 'gloria', 'upon'): 1,
#           ('gloria', 'upon', 'time'): 1,
#           ('upon', 'time', 'hollywood'): 2,
#           ('time', 'hollywood', 'convinc'): 1,
#           ('hollywood', 'convinc', 'sad'): 1,
#           ('convinc', 'sad', 'joaquin'): 1,
#           ('sad', 'joaquin', 'miss'): 1,
#           ('joaquin', 'miss', 'oscar'): 1,
#           ('miss', 'oscar', 'gladiat'): 1,
#           ('oscar', 'gladiat', 'compel'): 1,
#           ('gladiat', 'compel', 'villain'): 1,
#           ('compel', 'villain', 'quit'): 1,
#           ('villain', 'quit', 'confid'): 1,
#           ('quit', 'confid', 'win'): 1,
#           ('confid', 'win', 'joke'): 1,
#           ('win', 'joke', 'damn'): 1,
#           ('joke', 'damn', 'movi'): 1,
#           ('damn', 'movi', 'keep'): 1,
#           ('movi', 'keep', 'u'): 1,
#           ('keep', 'u', 'toe'): 1,
#           ('u', 'toe', 'time'): 1,
#           ('toe', 'time', 'predict'): 1,
#           ('time', 'predict', 'storylin'): 1,
#           ('predict', 'storylin', 'realli'): 1,
#           ('storylin', 'realli', 'deep'): 1,
#           ('realli', 'deep', 'interest'): 1,
#           ('deep', 'interest', 'plot'): 1,
#           ('interest', 'plot', 'forget'): 1,
#           ('plot', 'forget', 'mention'): 1,
#           ('forget', 'mention', 'act'): 1,
#           ('mention', 'act', 'damn'): 1,
#           ('act', 'damn', 'no'): 1,
#           ('damn', 'no', 'joaquin'): 1,
#           ('no', 'joaquin', 'teach'): 1,
#           ('joaquin', 'teach', 'u'): 1,
#           ('teach', 'u', 'realli'): 1,
#           ('u', 'realli', '5'): 1,
#           ('realli', '5', 'star'): 1,
#           ('5', 'star', 'act'): 1,
#           ('star', 'act', 'enjoy'): 1,
#           ('act', 'enjoy', 'movi'): 1,
#           ('enjoy', 'movi', 'get'): 1,
#           ('movi', 'get', 'wine'): 1,
#           ('get', 'wine', 'hand'): 1,
#           ('wine', 'hand', 'close'): 1,
#           ('hand', 'close', 'curtain'): 1,
#           ('close', 'curtain', 'turn'): 1,
#           ('curtain', 'turn', 'or'): 1,
#           ('turn', 'or', 'cellphon'): 1,
#           ('or', 'cellphon', 'put'): 1,
#           ('cellphon', 'put', 'disturb'): 1,
#           ('put', 'disturb', 'sign'): 1,
#           ('disturb', 'sign', 'or'): 1,
#           ('sign', 'or', 'door'): 1,
#           ('or', 'door', 'best'): 1,
#           ('door', 'best', 'dark'): 1,
#           ('best', 'dark', 'thrill'): 1,
#           ('dark', 'thrill', 'suspens'): 1,
#           ('thrill', 'suspens', 'movi'): 1,
#           ('suspens', 'movi', 'get'): 1,
#           ('movi', 'get', 'experi'): 1,
#           ('get', 'experi', 'give'): 1,
#           ('experi', 'give', 'watch'): 1,
#           ('give', 'watch', 'mani'): 1,
#           ('watch', 'mani', 'superhero'): 1,
#           ('mani', 'superhero', 'move'): 1,
#           ('superhero', 'move', 'come'): 1,
#           ('move', 'come', 'pike'): 1,
#           ('come', 'pike', 'often'): 1,
#           ('pike', 'often', 'compens'): 1,
#           ('often', 'compens', 'sensat'): 1,
#           ('compens', 'sensat', 'plot'): 1,
#           ('sensat', 'plot', 'involv'): 1,
#           ('plot', 'involv', 'great'): 1,
#           ('involv', 'great', 'special'): 1,
#           ('great', 'special', 'effect'): 1,
#           ('special', 'effect', 'nonstop'): 1,
#           ('effect', 'nonstop', 'action'): 1,
#           ('nonstop', 'action', 'fun'): 1,
#           ('action', 'fun', 'dont'): 1,
#           ('fun', 'dont', 'mean'): 1,
#           ('dont', 'mean', 'di'): 1,
#           ('mean', 'di', 'miss'): 1,
#           ('di', 'miss', 'truli'): 1,
#           ('miss', 'truli', 'psycholog'): 1,
#           ('truli', 'psycholog', 'drama'): 1,
#           ('psycholog', 'drama', 'dont'): 1,
#           ('drama', 'dont', 'get'): 1,
#           ('dont', 'get', 'head'): 1,
#           ('get', 'head', 'charact'): 1,
#           ('head', 'charact', 'film'): 1,
#           ('charact', 'film', 'incred'): 1,
#           ('film', 'incred', 'watch'): 1,
#           ('incred', 'watch', 'man'): 1,
#           ('watch', 'man', 'confront'): 1,
#           ('man', 'confront', 'demon'): 1,
#           ('confront', 'demon', 'see'): 1,
#           ('demon', 'see', 'made'): 1,
#           ('see', 'made', 'fun'): 1,
#           ('made', 'fun', 'attack'): 1,
#           ('fun', 'attack', 'beaten'): 1,
#           ('attack', 'beaten', 'respond'): 1,
#           ('beaten', 'respond', 'seen'): 1,
#           ('respond', 'seen', 'crazi'): 1,
#           ('seen', 'crazi', 'also'): 1,
#           ('crazi', 'also', 'find'): 1,
#           ('also', 'find', 'diminish'): 1,
#           ('find', 'diminish', 'eye'): 1,
#           ('diminish', 'eye', 'counselor'): 1,
#           ('eye', 'counselor', 'mother'): 1,
#           ('counselor', 'mother', 'kept'): 1,
#           ('mother', 'kept', 'secret'): 1,
#           ('kept', 'secret', 'thought'): 1,
#           ('secret', 'thought', 'gave'): 1,
#           ('thought', 'gave', 'u'): 1,
#           ('gave', 'u', 'foundat'): 1,
#           ('u', 'foundat', 'batman'): 1,
#           ('foundat', 'batman', 'method'): 1,
#           ('batman', 'method', 'without'): 1,
#           ('method', 'without', 'get'): 1,
#           ('without', 'get', 'deepli'): 1,
#           ('get', 'deepli', 'act'): 1,
#           ('deepli', 'act', 'atmospher'): 1,
#           ('act', 'atmospher', 'sophist'): 1,
#           ('atmospher', 'sophist', 'plot'): 1,
#           ('sophist', 'plot', 'make'): 1,
#           ('plot', 'make', 'realli'): 1,
#           ('make', 'realli', 'excel'): 1,
#           ('realli', 'excel', 'film'): 1,
#           ('excel', 'film', 'movi'): 1,
#           ('film', 'movi', 'affect'): 1,
#           ('movi', 'affect', 'way'): 1,
#           ('affect', 'way', 'make'): 1,
#           ('way', 'make', 'physic'): 1,
#           ('make', 'physic', 'pain'): 1,
#           ('physic', 'pain', 'experi'): 1,
#           ('pain', 'experi', 'good'): 1,
#           ('experi', 'good', 'way'): 1,
#           ('good', 'way', 'thought'): 1,
#           ('way', 'thought', 'film'): 1,
#           ('thought', 'film', 'good'): 1,
#           ('film', 'good', 'dont'): 1,
#           ('good', 'dont', 'get'): 1,
#           ('dont', 'get', 'hope'): 1,
#           ('get', 'hope', 'person'): 1,
#           ('hope', 'person', 'act'): 1,
#           ('person', 'act', 'amaz'): 1,
#           ('act', 'amaz', 'film'): 1,
#           ('amaz', 'film', 'good'): 1,
#           ('film', 'good', 'overal'): 1,
#           ('good', 'overal', 'think'): 1,
#           ('overal', 'think', 'masterpiec'): 1,
#           ('think', 'masterpiec', 'film'): 1,
#           ('masterpiec', 'film', 'year'): 1,
#           ('film', 'year', 'bit'): 1,
#           ('year', 'bit', 'vers'): 1,
#           ('bit', 'vers', 'throughout'): 1,
#           ('vers', 'throughout', 'review'): 1,
#           ('throughout', 'review', 'way'): 1,
#           ('review', 'way', 'dislik'): 1,
#           ('way', 'dislik', 'film'): 1,
#           ('dislik', 'film', 'thought'): 1,
#           ('film', 'thought', 'realli'): 1,
#           ('thought', 'realli', 'good'): 1,
#           ('realli', 'good', 'overhyp'): 1,
#           ('good', 'overhyp', 'feel'): 1,
#           ('overhyp', 'feel', 'though'): 1,
#           ('feel', 'though', 'lot'): 1,
#           ('though', 'lot', '1010'): 1,
#           ('lot', '1010', 'review'): 1,
#           ('1010', 'review', 'pure'): 1,
#           ('review', 'pure', 'base'): 1,
#           ('pure', 'base', 'fact'): 1,
#           ('base', 'fact', 'alreadi'): 1,
#           ('fact', 'alreadi', 'amaz'): 1,
#           ('alreadi', 'amaz', 'review'): 1,
#           ('amaz', 'review', 'peopl'): 1,
#           ('review', 'peopl', 'want'): 1,
#           ('peopl', 'want', 'carri'): 1,
#           ('want', 'carri', 'prais'): 1,
#           ('carri', 'prais', 'joke'): 1,
#           ('prais', 'joke', 'film'): 1,
#           ('joke', 'film', 'releas'): 1,
#           ('film', 'releas', 'random'): 1,
#           ('releas', 'random', 'guy'): 1,
#           ('random', 'guy', 'situat'): 1,
#           ('guy', 'situat', 'dont'): 1,
#           ('situat', 'dont', 'think'): 1,
#           ('dont', 'think', 'review'): 1,
#           ('think', 'review', 'would'): 1,
#           ('review', 'would', 'high'): 1,
#           ('would', 'high', 'mayb'): 1,
#           ('high', 'mayb', 'that'): 1,
#           ('mayb', 'that', 'point'): 1,
#           ('that', 'point', 'movi'): 1,
#           ('point', 'movi', 'caus'): 1,
#           ('movi', 'caus', 'audienc'): 1,
#           ('caus', 'audienc', 'consid'): 1,
#           ('audienc', 'consid', 'mani'): 1,
#           ('consid', 'mani', 'topic'): 1,
#           ('mani', 'topic', 'moral'): 1,
#           ('topic', 'moral', 'particularli'): 1,
#           ('moral', 'particularli', 'poor'): 1,
#           ('particularli', 'poor', 'choic'): 1,
#           ('poor', 'choic', 'made'): 1,
#           ('choic', 'made', 'joke'): 1,
#           ('made', 'joke', 'joke'): 1,
#           ('joke', 'joke', 'reliabl'): 1,
#           ('joke', 'reliabl', 'movi'): 1,
#           ('reliabl', 'movi', 'antagonist'): 1,
#           ('movi', 'antagonist', 'usual'): 1,
#           ('antagonist', 'usual', 'think'): 1,
#           ('usual', 'think', 'give'): 1,
#           ('think', 'give', 'realist'): 1,
#           ('give', 'realist', 'view'): 1,
#           ('realist', 'view', 'bad'): 1,
#           ('view', 'bad', 'peopl'): 1,
#           ('bad', 'peopl', 'usual'): 1,
#           ('peopl', 'usual', '100'): 1,
#           ('usual', '100', 'bad'): 1,
#           ('100', 'bad', 'way'): 1,
#           ('bad', 'way', 'societi'): 1,
#           ('way', 'societi', 'often'): 1,
#           ('societi', 'often', 'judg'): 1,
#           ('often', 'judg', 'import'): 1,
#           ('judg', 'import', 'know'): 1,
#           ('import', 'know', 'sympath'): 1,
#           ('know', 'sympath', 'joke'): 1,
#           ('sympath', 'joke', 'toward'): 1,
#           ('joke', 'toward', 'begin'): 1,
#           ('toward', 'begin', 'movi'): 1,
#           ('begin', 'movi', 'need'): 1,
#           ('movi', 'need', 'identifi'): 1,
#           ('need', 'identifi', 'threat'): 1,
#           ('identifi', 'threat', 'begin'): 1,
#           ('threat', 'begin', 'make'): 1,
#           ('begin', 'make', 'certain'): 1,
#           ('make', 'certain', 'bad'): 1,
#           ('certain', 'bad', 'choic'): 1,
#           ('bad', 'choic', 'movi'): 1,
#           ('choic', 'movi', 'suitabl'): 1,
#           ('movi', 'suitabl', 'adult'): 1,
#           ('suitabl', 'adult', 'will'): 1,
#           ('adult', 'will', 'pick'): 1,
#           ('will', 'pick', 'apart'): 1,
#           ('pick', 'apart', 'think'): 1,
#           ('apart', 'think', 'clinic'): 1,
#           ('think', 'clinic', 'isn'): 1,
#           ('clinic', 'isn', 'light'): 1,
#           ('isn', 'light', 'amus'): 1,
#           ('light', 'amus', 'substanc'): 1,
#           ('amus', 'substanc', 'make'): 1,
#           ('substanc', 'make', 'good'): 1,
#           ('make', 'good', 'agent'): 1,
#           ('good', 'agent', 'abl'): 1,
#           ('agent', 'abl', 'ponder'): 1,
#           ('abl', 'ponder', 'underli'): 1,
#           ('ponder', 'underli', 'theme'): 1,
#           ('underli', 'theme', 'hand'): 1,
#           ('theme', 'hand', 'thought'): 1,
#           ('hand', 'thought', 'isn'): 1,
#           ('thought', 'isn', 'best'): 1,
#           ('isn', 'best', 'movi'): 1,
#           ('best', 'movi', 'act'): 1,
#           ('movi', 'act', 'cinematographi'): 1,
#           ('act', 'cinematographi', 'sound'): 1,
#           ('cinematographi', 'sound', 'design'): 1,
#           ('sound', 'design', 'script'): 1,
#           ('design', 'script', 'phenomenon'): 1,
#           ('script', 'phenomenon', 'movi'): 1,
#           ('phenomenon', 'movi', 'triumph'): 1,
#           ('movi', 'triumph', 'joaquin'): 1,
#           ('triumph', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'deserv'): 1,
#           ('phoenix', 'deserv', 'oscar'): 1,
#           ('deserv', 'oscar', 'win'): 1,
#           ('oscar', 'win', 'th'): 1,
#           ('win', 'th', 'went'): 1,
#           ('th', 'went', 'film'): 1,
#           ('went', 'film', 'expect'): 1,
#           ('film', 'expect', 'allie'): 1,
#           ('expect', 'allie', 'classic'): 1,
#           ('allie', 'classic', 'base'): 1,
#           ('classic', 'base', 'review'): 1,
#           ('base', 'review', 'read'): 1,
#           ('review', 'read', 'end'): 1,
#           ('read', 'end', 'watch'): 1,
#           ('end', 'watch', 'decent'): 1,
#           ('watch', 'decent', 'film'): 1,
#           ('decent', 'film', 'overal'): 1,
#           ('film', 'overal', 'phoenix'): 1,
#           ('overal', 'phoenix', 'outstand'): 1,
#           ('phoenix', 'outstand', 'definit'): 1,
#           ('outstand', 'definit', 'part'): 1,
#           ('definit', 'part', 'feel'): 1,
#           ('part', 'feel', 'like'): 1,
#           ('feel', 'like', 'you'): 1,
#           ('like', 'you', 'seen'): 1,
#           ('you', 'seen', 'trailer'): 1,
#           ('seen', 'trailer', 'you'): 1,
#           ('trailer', 'you', 'seen'): 1,
#           ('you', 'seen', 'movi'): 1,
#           ('seen', 'movi', 'best'): 1,
#           ('movi', 'best', 'way'): 1,
#           ('best', 'way', 'describ'): 1,
#           ('way', 'describ', 'film'): 1,
#           ('describ', 'film', 'feel'): 1,
#           ('film', 'feel', 'like'): 1,
#           ('feel', 'like', '2'): 1,
#           ('like', '2', 'hour'): 1,
#           ('2', 'hour', 'version'): 1,
#           ('hour', 'version', 'trailer'): 1,
#           ('version', 'trailer', '2'): 1,
#           ('trailer', '2', 'hour'): 1,
#           ('2', 'hour', 'rel'): 1,
#           ('hour', 'rel', 'common'): 1,
#           ('rel', 'common', 'aunti'): 1,
#           ('common', 'aunti', 'felt'): 1,
#           ('aunti', 'felt', 'lot'): 1,
#           ('felt', 'lot', 'longerwhich'): 1,
#           ('lot', 'longerwhich', 'isn'): 1,
#           ('longerwhich', 'isn', 'good'): 1,
#           ('isn', 'good', 'id'): 1,
#           ('good', 'id', 'say'): 1,
#           ('id', 'say', 'much'): 1,
#           ('say', 'much', 'rental'): 1,
#           ('much', 'rental', 'theater'): 1,
#           ('rental', 'theater', 'movi'): 1,
#           ('theater', 'movi', 'kind'): 1,
#           ('movi', 'kind', 'just'): 1,
#           ('kind', 'just', 'need'): 1,
#           ('just', 'need', 'say'): 1,
#           ('need', 'say', 'everyth'): 1,
#           ('say', 'everyth', 'movi'): 1,
#           ('everyth', 'movi', 'wast'): 1,
#           ('movi', 'wast', 'everi'): 1,
#           ('wast', 'everi', 'singl'): 1,
#           ('everi', 'singl', 'way'): 1,
#           ('singl', 'way', 'joke'): 1,
#           ('way', 'joke', 'isn'): 1,
#           ('joke', 'isn', 'awesom'): 1,
#           ('isn', 'awesom', 'comic'): 1,
#           ('awesom', 'comic', 'book'): 1,
#           ('comic', 'book', 'movi'): 2,
#           ('book', 'movi', 'awesom'): 1,
#           ('movi', 'awesom', 'movi'): 1,
#           ('awesom', 'movi', 'period'): 1,
#           ('movi', 'period', 'offer'): 1,
#           ('period', 'offer', 'easi'): 1,
#           ('offer', 'easi', 'answer'): 1,
#           ('easi', 'answer', 'settl'): 1,
#           ('answer', 'settl', 'question'): 1,
#           ('settl', 'question', 'rais'): 1,
#           ('question', 'rais', 'cruel'): 1,
#           ('rais', 'cruel', 'societi'): 1,
#           ('cruel', 'societi', 'declin'): 1,
#           ('societi', 'declin', 'joaquin'): 1,
#           ('declin', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'fulli'): 1,
#           ('phoenix', 'fulli', 'commit'): 1,
#           ('fulli', 'commit', 'perform'): 1,
#           ('commit', 'perform', 'told'): 1,
#           ('perform', 'told', 'phillip'): 1,
#           ('told', 'phillip', 'wast'): 1,
#           ('phillip', 'wast', 'albeit'): 1,
#           ('wast', 'albeit', 'loo'): 1,
#           ('albeit', 'loo', 'invent'): 1,
#           ('loo', 'invent', 'do'): 1,
#           ('invent', 'do', 'sourc'): 1,
#           ('do', 'sourc', 'materi'): 1,
#           ('sourc', 'materi', 'make'): 1,
#           ('materi', 'make', 'joke'): 1,
#           ('make', 'joke', 'film'): 1,
#           ('joke', 'film', 'leav'): 1,
#           ('film', 'leav', 'comic'): 1,
#           ('leav', 'comic', 'book'): 1,
#           ('comic', 'book', 'fan'): 1,
#           ('book', 'fan', 'nonfan'): 1,
#           ('fan', 'nonfan', 'alik'): 1,
#           ('nonfan', 'alik', 'disturb'): 1,
#           ('alik', 'disturb', 'move'): 1,
#           ('disturb', 'move', 'right'): 1,
#           ('move', 'right', 'way'): 1,
#           ('right', 'way', 'realli'): 1,
#           ('way', 'realli', 'understand'): 1,
#           ('realli', 'understand', 'ten'): 1,
#           ('understand', 'ten', 'sure'): 1,
#           ('ten', 'sure', 'good'): 1,
#           ('sure', 'good', 'movi'): 1,
#           ('good', 'movi', 'good'): 1,
#           ('movi', 'good', 'act'): 1,
#           ('good', 'act', 'nice'): 1,
#           ('act', 'nice', 'shoot'): 1,
#           ('nice', 'shoot', 'plot'): 1,
#           ('shoot', 'plot', 'intrigu'): 1,
#           ('plot', 'intrigu', 'time'): 1,
#           ('intrigu', 'time', 'realli'): 1,
#           ('time', 'realli', 'long'): 1,
#           ('realli', 'long', 'somewhat'): 1,
#           ('long', 'somewhat', 'bore'): 1,
#           ('somewhat', 'bore', 'need'): 1,
#           ('bore', 'need', 'doublecheck'): 1,
#           ('need', 'doublecheck', 'gene'): 1,
#           ('doublecheck', 'gene', 'see'): 1,
#           ('gene', 'see', 'drama'): 1,
#           ('see', 'drama', 'crime'): 1,
#           ('drama', 'crime', 'drama'): 1,
#           ('crime', 'drama', 'thrill'): 1,
#           ('drama', 'thrill', 'said'): 1,
#           ('thrill', 'said', 'would'): 1,
#           ('said', 'would', 'put'): 1,
#           ('would', 'put', 'mayb'): 1,
#           ('put', 'mayb', '90'): 1,
#           ('mayb', '90', 'drama'): 1,
#           ('90', 'drama', 'rest'): 1,
#           ('drama', 'rest', 'thrill'): 1,
#           ('rest', 'thrill', 'miss'): 1,
#           ('thrill', 'miss', 'dialogu'): 1,
#           ('miss', 'dialogu', 'depth'): 1,
#           ('dialogu', 'depth', 'substanc'): 1,
#           ('depth', 'substanc', 'plot'): 1,
#           ('substanc', 'plot', 'realli'): 1,
#           ('plot', 'realli', 'somewhat'): 1,
#           ('realli', 'somewhat', 'crazi'): 1,
#           ('somewhat', 'crazi', 'person'): 1,
#           ('crazi', 'person', 'becom'): 1,
#           ('person', 'becom', 'bit'): 1,
#           ('becom', 'bit', 'brazier'): 1,
#           ('bit', 'brazier', 'sure'): 1,
#           ('brazier', 'sure', 'underton'): 1,
#           ('sure', 'underton', 'societi'): 1,
#           ('underton', 'societi', 'system'): 1,
#           ('societi', 'system', 'mean'): 1,
#           ('system', 'mean', 'charact'): 1,
#           ('mean', 'charact', 'peopl'): 1,
#           ('charact', 'peopl', 'bring'): 1,
#           ('peopl', 'bring', 'creat'): 1,
#           ('bring', 'creat', 'evil'): 1,
#           ('creat', 'evil', 'beast'): 1,
#           ('evil', 'beast', 'later'): 1,
#           ('beast', 'later', 'want'): 1,
#           ('later', 'want', 'destroy'): 1,
#           ('want', 'destroy', 'everyth'): 1,
#           ('destroy', 'everyth', 'absolut'): 1,
#           ('everyth', 'absolut', 'think'): 1,
#           ('absolut', 'think', 'intrigu'): 1,
#           ('think', 'intrigu', 'stori'): 1,
#           ('intrigu', 'stori', 'plot'): 1,
#           ('stori', 'plot', 'dialogu'): 1,
#           ('plot', 'dialogu', 'enough'): 1,
#           ('dialogu', 'enough', 'give'): 1,
#           ('enough', 'give', 'ten'): 1,
#           ('give', 'ten', 'worthi'): 1,
#           ('ten', 'worthi', 'watch'): 1,
#           ('worthi', 'watch', 'ye'): 1,
#           ('watch', 'ye', 'amaz'): 1,
#           ('ye', 'amaz', 'stop'): 1,
#           ('amaz', 'stop', 'watch'): 1,
#           ('stop', 'watch', 'move'): 1,
#           ('watch', 'move', 'joaquin'): 1,
#           ('move', 'joaquin', 'phoenix'): 1,
#           ('joaquin', 'phoenix', 'award'): 1,
#           ('phoenix', 'award', 'oscar'): 1,
#           ('award', 'oscar', 'tremend'): 1,
#           ('oscar', 'tremend', 'act'): 1,
#           ('tremend', 'act', 'quit'): 1,
#           ('act', 'quit', 'reli'): 1,
#           ('quit', 'reli', 'critic'): 1,
#           ('reli', 'critic', 'review'): 1,
#           ('critic', 'review', 'year'): 1,
#           ('review', 'year', 'ago'): 1,
#           ('year', 'ago', 'notic'): 1,
#           ('ago', 'notic', 'movi'): 1,
#           ('notic', 'movi', 'critic'): 1,
#           ('movi', 'critic', 'rate'): 1,
#           ('critic', 'rate', 'low'): 1,
#           ('rate', 'low', 'viewer'): 1,
#           ('low', 'viewer', 'rate'): 1,
#           ('viewer', 'rate', 'high'): 1,
#           ('rate', 'high', 'said'): 1,
#           ('high', 'said', 'point'): 1,
#           ('said', 'point', 'critic'): 1,
#           ('point', 'critic', 'movi'): 1,
#           ('critic', 'movi', 'oh'): 1,
#           ('movi', 'oh', 'wrong'): 1,
#           ('oh', 'wrong', 'went'): 1,
#           ('wrong', 'went', 'saw'): 1,
#           ('went', 'saw', 'tone'): 1,
#           ('saw', 'tone', 'mon'): 1,
#           ('tone', 'mon', 'went'): 1,
#           ('mon', 'went', 'skeptic'): 1,
#           ('went', 'skeptic', 'w'): 1,
#           ('skeptic', 'w', 'low'): 1,
#           ('w', 'low', 'expect'): 1,
#           ('low', 'expect', 'knew'): 1,
#           ('expect', 'knew', 'expect'): 1,
#           ('knew', 'expect', 'typic'): 1,
#           ('expect', 'typic', 'super'): 1,
#           ('typic', 'super', 'hero'): 1,
#           ('super', 'hero', 'movi'): 2,
#           ('hero', 'movi', 'got'): 1,
#           ('movi', 'got', 'masterpiec'): 1,
#           ('got', 'masterpiec', 'went'): 1,
#           ('masterpiec', 'went', 'expect'): 1,
#           ...})

# %% [markdown]
# # **Question 2: Undersand TF-IDF and Document representation**

# %% [markdown]
# (20 points). Starting from the documents (all the reviews, or abstracts, or tweets) collected for assignment two, write a python program:
#
# (1) To build the **documents-terms weights (tf*idf) matrix bold text**.
#
# (2) To rank the documents with respect to query (design a query by yourself, for example, "An Outstanding movie with a haunting performance and best character development") by using **cosine similarity**.

# %%
# Write your code here
import math
def tf_idf_value(sentence,word):
  size = len(sentence.split(" "))
  tf_value = sentence.count(word)/size
  idf_value = 0
  if(tf_value!=0):
    idf_value = math.log(size)/sentence.count(word)
  else:
    return 0;
  return tf_value*idf_value

sentences = df["Spelling Correction"].values.tolist()
tokens_list = set([j for i in sentences for j in i.split(" ")])
tf_idf = pd.DataFrame(tokens_list,columns=["token"])
count = 0
for i in sentences:
  tf_idf[str(count)] = tf_idf["token"].apply(lambda x : tf_idf_value(i,x))
  count+=1

tf_idf
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:18: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#            token         0         1         2        3         4         5  \
# 0                 0.081918  0.093937  0.055855  0.08065  0.083231  0.058163
# 1           soon  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2       spectrum  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 3          cameo  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 4         partie  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# ...          ...       ...       ...       ...      ...       ...       ...
# 2322  regardless  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2323        rich  0.000000  0.000000  0.055855  0.00000  0.000000  0.000000
# 2324      origin  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2325       novel  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
# 2326   reference  0.000000  0.000000  0.000000  0.00000  0.000000  0.000000
#
#              6         7         8  ...       115      116       117  \
# 0     0.110774  0.035297  0.070931  ...  0.015735  0.15497  0.047936
# 1     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 2     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 3     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 4     0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# ...        ...       ...       ...  ...       ...      ...       ...
# 2322  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 2323  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 2324  0.000000  0.000000  0.000000  ...  0.015735  0.00000  0.000000
# 2325  0.000000  0.000000  0.000000  ...  0.000000  0.00000  0.000000
# 2326  0.000000  0.035297  0.000000  ...  0.015735  0.00000  0.000000
#
#            118       119  120       121       122       123       124
# 0     0.188504  0.020007  0.0  0.077095  0.298627  0.088992  0.027041
# 1     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 3     0.000000  0.020007  0.0  0.000000  0.000000  0.000000  0.000000
# 4     0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# ...        ...       ...  ...       ...       ...       ...       ...
# 2322  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2323  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2324  0.000000  0.020007  0.0  0.000000  0.000000  0.000000  0.027041
# 2325  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
# 2326  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.000000
#
# [2327 rows x 126 columns]

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
query_sentence = 'The perfect portrait of a decline to insanity" & Joaquin Phoenix portrays this flawlessly in a performance of a lifetime. Choreographed impeccably by Todd Phillips & is nothing short of breathtaking. The cinematography & backdrop ideology of such an original film for such a complex character is only complimented by the superb soundtrack & acting. A hauntingly beautiful film & A Definate 10/10. Edit: Bring on part 2 plssssss!. We all want it!.'
X_list = word_tokenize(query_sentence)
sw = stopwords.words('english') 
X_set = {w for w in X_list if not w in sw}

# %%
def compute_vector(X_set, Y_set):
  rvector = X_set.union(Y_set)
  l1 =[];l2 =[]
  for w in rvector: 
      if w in X_set: l1.append(1)
      else: l1.append(0) 
      if w in Y_set: l2.append(1) 
      else: l2.append(0)
  return rvector, l1, l2

# %%
def compute_cosine(rvector, l1, l2):
  c = 0
  for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
  cosine = c / float((sum(l1)*sum(l2))**0.5) 
  return cosine

# %% [markdown]
# # **Question 3: Create your own word embedding model**

# %% [markdown]
# (20 points). Use the data you collected for assignment two to build a word embedding model:
#
# (1) Train a 300-dimension word embedding (it can be word2vec, glove, ulmfit, bert, or others).
#
# (2) Visualize the word embedding model you created.
#
# Reference: https://machinelearningmastery.com/develop-word-embeddings-python-gensim/

# %%
from gensim.models import Word2Vec

# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# summarize the loaded model
print(model)
# summarize vocabulary
words = list(model.wv.vocab)
print(words)
# access vector for one word
print(model['sentence'])
# save model
model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)
# Out:
# Word2Vec(vocab=14, size=100, alpha=0.025)
# ['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec', 'second', 'yet', 'another', 'one', 'more', 'and', 'final']
# [-1.6864716e-03 -2.1070207e-03  1.4183939e-03  4.9229958e-03
#   4.2708223e-03 -1.3083545e-03 -1.4661376e-03  1.7044619e-03
#   3.9471695e-03  1.6109402e-03 -1.9217926e-03 -2.0023684e-03
#   2.1967806e-03 -1.6393649e-03 -1.9670792e-03  2.6215834e-03
#   1.7313031e-03  4.7627646e-03  4.5037488e-03  4.5818710e-03
#  -1.5716768e-03  1.9519440e-03  3.5165940e-04  2.4531183e-03
#  -2.2480218e-03 -9.3159504e-04  4.0399851e-03 -2.0860541e-03
#  -4.7726189e-03  2.1155921e-03  1.7695734e-03  4.7282963e-03
#  -9.5772848e-04  5.0570938e-04  2.0006287e-04 -4.1027125e-03
#  -2.2657216e-03 -1.8394151e-03 -2.9763591e-03  3.9591491e-03
#   6.2792347e-04 -1.6218414e-04  4.1861702e-03 -3.8813779e-03
#   4.2043473e-03 -1.6556499e-03 -3.9347383e-04  1.0074122e-03
#  -1.3184750e-03  3.5440933e-03 -3.2310437e-03 -1.5747214e-03
#   7.2434239e-05 -1.3573715e-03  3.8720444e-03 -1.3769900e-03
#  -3.2883910e-03 -1.5913870e-03  4.1696639e-03  3.4245320e-03
#  -3.1486622e-03  3.7316841e-04 -2.6979065e-03  1.4954146e-03
#   1.0887878e-03 -3.4150262e-03  4.4224681e-03  5.7684589e-04
#  -4.1983760e-04 -1.9763445e-04  4.0593836e-03  4.7950763e-03
#  -3.6259813e-03  9.2570635e-04  8.3446631e-04  1.7207781e-03
#   3.5754931e-03  3.2978810e-03  4.4428254e-03  1.5458595e-03
#   4.4817864e-03  1.3106804e-03  2.9542942e-03 -2.1730203e-03
#  -7.2052149e-05 -3.3024775e-03 -4.6479930e-03 -5.1799044e-04
#   3.0690131e-03 -1.5635790e-03  3.5067911e-03  2.0239865e-03
#  -1.0716392e-03 -3.8224142e-03 -1.9401109e-03  2.6533179e-04
#   4.4135917e-03 -3.0708455e-03 -2.1721257e-03 -1.8834881e-03]
# Word2Vec(vocab=14, size=100, alpha=0.025)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   del sys.path[0]

# %% [markdown]
# # **Question 4: Create your own training and evaluation data for sentiment analysis**

# %% [markdown]
# (15 points). **You dodn't need to write program for this question!** Read each review (abstract or tweet) you collected in detail, and annotate each review with a sentiment (positive, negative, or neutral). Save the annotated dataset into a csv file with three columns (first column: document_id, clean_text, sentiment), upload the csv file to GitHub and submit the file link blew. This datset will be used for assignment four: sentiment analysis and text classification.

# %%
# The GitHub link of your final csv file



# Link: https://github.com/Kalyang099/Kalyan_INFO5731_Spring2022/blob/main/reviwes.csv
